# %%
import pandas as pd

# %%
# errorRows=[71,79,227,456,506,508,560,918,1126,1153,1813,1826,1916,2025,2029,2046]

# %%
PetProducts1=pd.read_csv("Resources/PetProducts.csv",error_bad_lines=False)
                        
#                          skiprows=errorRows) nrows=50000
# Out:
# b'Skipping line 72: expected 15 fields, saw 17\nSkipping line 80: expected 15 fields, saw 17\nSkipping line 228: expected 15 fields, saw 16\nSkipping line 457: expected 15 fields, saw 17\nSkipping line 507: expected 15 fields, saw 16\nSkipping line 509: expected 15 fields, saw 20\nSkipping line 561: expected 15 fields, saw 19\nSkipping line 919: expected 15 fields, saw 16\nSkipping line 1127: expected 15 fields, saw 17\nSkipping line 1154: expected 15 fields, saw 16\nSkipping line 1814: expected 15 fields, saw 16\nSkipping line 1827: expected 15 fields, saw 16\nSkipping line 1917: expected 15 fields, saw 16\nSkipping line 2026: expected 15 fields, saw 16\nSkipping line 2030: expected 15 fields, saw 19\nSkipping line 2047: expected 15 fields, saw 16\nSkipping line 2189: expected 15 fields, saw 16\nSkipping line 2221: expected 15 fields, saw 16\nSkipping line 2378: expected 15 fields, saw 17\nSkipping line 2408: expected 15 fields, saw 16\nSkipping line 2500: expected 15 fields, saw 17
# ...

# %%
PetProducts1.head()

# %%
PetProducts1.shape
# Out:
# (2606062, 15)

# %%
PetProducts1.to_csv("Resources/CleanedPetPRoducts.csv",index=False)

# %%
# pettest=pd.read_csv('Resources/PetProducts.csv',usecols=)
# pettest.head()

# %% [markdown]
# # Read from Cleaned CSV

# %%
wholePetProducts=pd.read_csv('Resources/CleanedPetPRoducts.csv')
wholePetProducts.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     28794885   REAKC26P07MDN  B00Q0K9604       510387886
# 1          US     11488901  R3NU7OMZ4HQIEG  B00MBW5O9W       912374672
# 2          US     43214993  R14QJW3XF8QO1P  B0084OHUIO       902215727
# 3          US     12835065  R2HB7AX0394ZGY  B001GS71K2       568880110
# 4          US     26334022   RGKMPDQGSAHR3  B004ABH1LG       692846826
#
#                                        product_title product_category  \
# 0                   (8-Pack) EZwhelp Belly Band/Wrap     Pet Products
# 1  Warren Eckstein's Hugs & Kisses Vitamin Minera...     Pet Products
# 2  Tyson's True Chews Premium Jerky - 12 ounce Ch...     Pet Products
# 3                      Soft Side Pet Crate, Navy/Tan     Pet Products
# 4  EliteField 3-Door Folding Soft Dog Crate, Indo...     Pet Products
#
#   star_rating helpful_votes total_votes vine verified_purchase  \
# ...

# %%
PetcoProducts=wholePetProducts[wholePetProducts.product_title.str.contains('Petco',na=False)]

# %%
PetcoProducts.to_csv("Resources/PetcoProducts.csv",index=False)

# %%
HillsProducts=wholePetProducts[wholePetProducts.product_title.str.contains('Hills',na=False)]
HillsProducts.head()
# Out:
#      marketplace  customer_id       review_id  product_id  product_parent  \
# 2399          US     44925197  R1ZZIBR29QUXWC  B00DURIQU6        65188077
# 3463          US     47024610  R3H41X9SJ4RY79  B00DURIQUQ        65188077
# 3916          US     40275226  R1WBBKJX68B6UI  B00DURIQU6        65188077
# 5269          US     10933753  R22VBC44X4GS4U  B008Y508SW       487627830
# 6452          US     51064757  R2PAULISTHCFGT  B00DURIQU6        65188077
#
#                                 product_title product_category star_rating  \
# 2399  Hills Ideal Balance Soft-Baked Naturals     Pet Products           5
# 3463  Hills Ideal Balance Soft-Baked Naturals     Pet Products           5
# 3916  Hills Ideal Balance Soft-Baked Naturals     Pet Products           5
# 5269   Hills Hypoallergenic Cat Treats 2.5 oz     Pet Products           3
# 6452  Hills Ideal Balance Soft-Baked Naturals     Pet Products           5
#
# ...

# %%
HillsProducts.to_csv("Resources/HillsProducts.csv",index=False)

# %%
# PetSmartProducts.head(1)
# PetSmartProducts['product_title'] .loc[PetSmartProducts['product_id']=='B000P278UI']

# %%
HillsProducts.shape
# Out:
# (470, 15)

# %%
PurinaProducts=wholePetProducts[wholePetProducts.product_title.str.contains('Purina',na=False)]
print(PurinaProducts.shape)
PurinaProducts.head()
# Out:
# (30537, 15)
#     marketplace  customer_id       review_id  product_id  product_parent  \
# 24           US     52594316  R3G0P137V9BYYL  B00LM0E17A       605471252
# 44           US     36430094  R3FPCEPAL8LX3N  B001E530FW       211785610
# 164          US      3829465  R2B28IZ7RBMNUD  B0012KCUNC       468282692
# 173          US     24706073   RRGXNMAUST8XW  B0002AQ0BQ       808147210
# 246          US     43824781  R12TIHZFWIN3Q0  B001G0NL2W       960882665
#
#                                          product_title product_category  \
# 24   Purina Waggin Train Chicken Jerky Dog Treats, ...     Pet Products
# 44   Purina Tidy Cats Breeze Litter System Cat Pell...     Pet Products
# 164  Purina Fancy Feast Classic Gourmet Wet Cat Foo...     Pet Products
# 173       Purina Yesterday's News Unscented Cat Litter     Pet Products
# 246  Purina Fancy Feast Kitten Gourmet Wet Cat Food...     Pet Products
#
#     star_rating helpful_votes total_votes vine verified_purchase  \
# ...

# %%
PurinaProducts.to_csv("Resources/PurinaProducts.csv",index=False)

# %%
PedigreeProducts=wholePetProducts[wholePetProducts.product_title.str.contains('Pedigree',na=False)]
print(PedigreeProducts.shape)
PedigreeProducts.head()
# Out:
# (1370, 15)
#      marketplace  customer_id       review_id  product_id  product_parent  \
# 3372          US       674501  R3BTTP1SFIYOWA  B004UMN15A       855131516
# 4001          US     12394285  R2XUCSDF6G0O1D  B00GFZYUCS       801209377
# 5978          US     51107411  R39E51KTCD2HKE  B002CZLOIS       237302314
# 6329          US     37628916  R2I57VJXP5AMNN  B00CU2CMOI       253558120
# 7657          US      5120229  R32HN7E0X6POEN  B00CU2CMOI       253558120
#
#                                           product_title product_category  \
# 3372  Pedigree Dentastix Daily Oral Care Snack Food ...     Pet Products
# 4001  Pedigree Breathbuster Biscuit Treats for Adult...     Pet Products
# 5978                            Pedigree Mini DentaStix     Pet Products
# 6329  Pedigree Dentastix 51-Treat Variety Pack, 2.76...     Pet Products
# 7657  Pedigree Dentastix 51-Treat Variety Pack, 2.76...     Pet Products
#
#      star_rating helpful_votes total_votes vine verified_purchase  \
# ...

# %%
PedigreeProducts.to_csv("Resources/PedigreeProducts.csv",index=False)

# %%
# WholeheartedProducts=wholePetProducts[wholePetProducts.product_title.str.contains('heart',na=False)]
# print(WholeheartedProducts.shape)
# WholeheartedProducts.head()
